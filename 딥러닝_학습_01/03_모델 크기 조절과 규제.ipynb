# %% [markdown]
# # 학습 목표
# * 딥러닝 모델의 크기를 조절해봅니다.
# * 효과적인 딥러닝 모델 학습을 위한 규제를 해봅니다.

# %% [markdown]
# # 01 모델 크기 조절
# * 레이어의 유닛수를 증가 또는 감소시켜 모델 전체 파라미터 수를 증가하거나 감소시킬 수 있다.
# * 레이어의 수를 증가시켜 더 깊은 신경망을 만들어 모델의 크기를 증가시킬 수 있다.
# * 데이터의 규모가 클수록 크고 깊은 모델에서 더 좋은 성능을 보여준다.
# * 데이터에 비해 모델이 너무 크면 과대적합이 발생할 수 있다.
# * 결론적으로 데이터의 규모에 따라 모델의 수를 적절하게 조절해야한다.

# %% [markdown]
# **모델의 크기 조절 방법에 따라 모델 성능의 결과가 어떻게 차이가 나는지 비교해보기**
# ### 데이터 로드 및 전처리

# %% [markdown]
# * 먼저 모델의 학습에 사용하기 위해 원-핫 인코딩(one-hot encoding)을 위한 함수를 정의
# * imdb.load_data()를 통해 IMDB 데이터를 다운로드한 뒤, 10000 차원의 학습 데이터로 원-핫 인코딩을 수행

# %%
from keras.datasets import imdb
import numpy as np

def one_hot_encoding(data, dim=10000): # 아래 imdb.load_data의 num_words를 10000으로 설정할 예정이기 때문에 dim도 10000으로 맞춰줍니다.
  results = np.zeros((len(data), dim))
  for i, d in enumerate(data):
    results[i, d] = 1.
  return results

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)

x_train = one_hot_encoding(train_data)
x_test = one_hot_encoding(test_data)

y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %% [markdown]
# ### 모델 구성 및 컴파일
# * IMDB 데이터셋에 대해 분류하는 모델로서 기존에 정의했던 3개의 Dense 레이어를 가지는 딥러닝 모델을 정의
# * rmsprop 옵티마이저, binary_crossentropy 손실 함수, accuracy 지표를 사용하도록 컴파일
# * summary()를 통해 확인해보면, 모델의 전체 파라미터의 수가 1,296,769개인 것을 알 수 있다.

# %%
import tensorflow as tf
from tensorflow.keras import models, layers

model = models.Sequential()
model.add(layers.Dense(128, activation='relu', input_shape=(10000, ), name='input'))
model.add(layers.Dense(128, activation='relu', name='hidden'))
model.add(layers.Dense(1, activation='sigmoid', name='output'))

model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# C:\Users\nini\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (Dense)                   │ (None, 128)            │     1,280,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden (Dense)                  │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,296,769 (4.95 MB)
#  Trainable params: 1,296,769 (4.95 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 모델 학습
# * 딥러닝 모델을 fit()을 이용해 학습

# %%
history = model.fit(x_train, y_train,
                    epochs=30,
                    batch_size=512,
                    validation_data=(x_test, y_test))
# Out:
# Epoch 1/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 323ms/step - accuracy: 0.6959 - loss: 0.5535 - val_accuracy: 0.8357 - val_loss: 0.3822
# Epoch 2/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - accuracy: 0.8921 - loss: 0.2721 - val_accuracy: 0.8882 - val_loss: 0.2734
# Epoch 3/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - accuracy: 0.9182 - loss: 0.2098 - val_accuracy: 0.8604 - val_loss: 0.3354
# Epoch 4/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.9345 - loss: 0.1721 - val_accuracy: 0.8846 - val_loss: 0.2897
# Epoch 5/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9486 - loss: 0.1379 - val_accuracy: 0.8802 - val_loss: 0.3097
# Epoch 6/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.9658 - loss: 0.1008 - val_accuracy: 0.8526 - val_loss: 0.4170
# Epoch 7/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.9609 - loss: 0.1014 - val_accuracy: 0.8766 - val_loss: 0.3699
# Epoch 8/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 0.9826 - loss: 0.0564 - val_accuracy: 0.8777 - val_loss: 0.3774
# Epoch 9/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - accuracy: 0.9905 - loss: 0.0368 - val_accuracy: 0.8755 - val_loss: 0.4506
# Epoch 10/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.9914 - loss: 0.0351 - val_accuracy: 0.8727 - val_loss: 0.4679
# Epoch 11/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9935 - loss: 0.0227 - val_accuracy: 0.8748 - val_loss: 0.4952
# Epoch 12/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9973 - loss: 0.0130 - val_accuracy: 0.8744 - val_loss: 0.4578
# Epoch 13/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9999 - loss: 0.0043 - val_accuracy: 0.8740 - val_loss: 0.5907
# Epoch 14/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9946 - loss: 0.0223 - val_accuracy: 0.8730 - val_loss: 0.5517
# Epoch 15/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.8740 - val_loss: 0.6432
# Epoch 16/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 0.9906 - loss: 0.0351 - val_accuracy: 0.8742 - val_loss: 0.5946
# Epoch 17/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.8745 - val_loss: 0.6734
# Epoch 18/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.9952 - loss: 0.0200 - val_accuracy: 0.8732 - val_loss: 0.6045
# Epoch 19/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 1.0000 - loss: 8.6503e-04 - val_accuracy: 0.8744 - val_loss: 0.7019
# Epoch 20/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 1.0000 - loss: 4.3461e-04 - val_accuracy: 0.8739 - val_loss: 0.7576
# Epoch 21/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 1.0000 - loss: 2.6814e-04 - val_accuracy: 0.8738 - val_loss: 0.7908
# Epoch 22/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 1.0000 - loss: 1.9893e-04 - val_accuracy: 0.8736 - val_loss: 0.8247
# Epoch 23/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 1.0000 - loss: 1.5045e-04 - val_accuracy: 0.8734 - val_loss: 0.8465
# Epoch 24/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 1.0000 - loss: 1.2418e-04 - val_accuracy: 0.8738 - val_loss: 0.8650
# Epoch 25/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 1.0000 - loss: 9.9724e-05 - val_accuracy: 0.8739 - val_loss: 0.8782
# Epoch 26/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 1.0000 - loss: 8.2865e-05 - val_accuracy: 0.8737 - val_loss: 0.8939
# Epoch 27/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 1.0000 - loss: 7.4244e-05 - val_accuracy: 0.8739 - val_loss: 0.9043
# Epoch 28/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 1.0000 - loss: 6.7078e-05 - val_accuracy: 0.8738 - val_loss: 0.9170
# Epoch 29/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 1.0000 - loss: 6.8255e-05 - val_accuracy: 0.8738 - val_loss: 0.9256
# Epoch 30/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 1.0000 - loss: 5.7266e-05 - val_accuracy: 0.8737 - val_loss: 0.9343

# %% [markdown]
# * 모델의 지표 결과로 loss, val_loss, accuracy, val_accuracy를 차트로 살펴보기

# %%
import matplotlib.pyplot as plt

history_dict = history.history

loss = history_dict['loss']
val_loss = history_dict['val_loss']
epochs = range(1, len(loss) + 1)

fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, 'b--', label='train_loss')
ax1.plot(epochs, val_loss, 'r--', label='val_loss')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, accuracy, 'b--', label='train_accuracy')
ax2.plot(epochs, val_accuracy, 'r--', label='val_accuracy')
ax2.set_title('Train and Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()

# %% [markdown]
# * 결과를 보면, 딥러닝 모델이 과대적합된 상태인 것을 알 수 있다.
# * 따라서 과대적합을 해결하기 위한 방법을 찾아야합니다.

# %% [markdown]
# ### 모델 크기 증가
# * 먼저 모델의 크기를 증가시키면 어떻게 될지 살펴 보기
# * Dense 레이어의 유닛수를 128에서 2048로 크게 증가시켜서 모델의 전체 파라미터 수가 24,680,449개가 된것을 확인할 수 있다.

# %%
b_model = models.Sequential()
b_model.add(layers.Dense(2048, activation='relu', input_shape=(10000, ), name='input3'))
b_model.add(layers.Dense(2048, activation='relu', name='hidden3'))
b_model.add(layers.Dense(1, activation='sigmoid', name='output3'))
b_model.compile(optimizer='rmsprop',
                loss='binary_crossentropy',
                metrics=['accuracy'])
b_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input3 (Dense)                  │ (None, 2048)           │    20,482,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden3 (Dense)                 │ (None, 2048)           │     4,196,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output3 (Dense)                 │ (None, 1)              │         2,049 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,680,449 (94.15 MB)
#  Trainable params: 24,680,449 (94.15 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
b_model_history = b_model.fit(x_train, y_train,
                              epochs=30,
                              batch_size=512, 
                              validation_data=(x_test, y_test))
# Out:
# Epoch 1/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 809ms/step - accuracy: 0.6239 - loss: 0.7016 - val_accuracy: 0.8682 - val_loss: 0.3399
# Epoch 2/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 29s 591ms/step - accuracy: 0.8874 - loss: 0.2885 - val_accuracy: 0.8783 - val_loss: 0.2900
# Epoch 3/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 29s 589ms/step - accuracy: 0.9189 - loss: 0.2046 - val_accuracy: 0.8418 - val_loss: 0.3812
# Epoch 4/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 571ms/step - accuracy: 0.9412 - loss: 0.1585 - val_accuracy: 0.8885 - val_loss: 0.2851
# Epoch 5/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 27s 558ms/step - accuracy: 0.9602 - loss: 0.1108 - val_accuracy: 0.8823 - val_loss: 0.3293
# Epoch 6/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 28s 567ms/step - accuracy: 0.9741 - loss: 0.0800 - val_accuracy: 0.8853 - val_loss: 0.3333
# Epoch 7/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 27s 562ms/step - accuracy: 0.9881 - loss: 0.0449 - val_accuracy: 0.8832 - val_loss: 0.3945
# Epoch 8/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 28s 568ms/step - accuracy: 0.9915 - loss: 0.0332 - val_accuracy: 0.8826 - val_loss: 0.4430
# Epoch 9/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 28s 570ms/step - accuracy: 0.9953 - loss: 0.0213 - val_accuracy: 0.8807 - val_loss: 0.4150
# Epoch 10/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 29s 584ms/step - accuracy: 0.9999 - loss: 0.0048 - val_accuracy: 0.8817 - val_loss: 0.5448
# Epoch 11/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 29s 591ms/step - accuracy: 0.9939 - loss: 0.0338 - val_accuracy: 0.8804 - val_loss: 0.4742
# Epoch 12/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 40s 566ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.8812 - val_loss: 0.6138
# Epoch 13/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 28s 577ms/step - accuracy: 1.0000 - loss: 7.1883e-04 - val_accuracy: 0.8810 - val_loss: 0.6671
# Epoch 14/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 39s 531ms/step - accuracy: 1.0000 - loss: 4.0962e-04 - val_accuracy: 0.8811 - val_loss: 0.7084
# Epoch 15/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 553ms/step - accuracy: 1.0000 - loss: 2.5408e-04 - val_accuracy: 0.8806 - val_loss: 0.7393
# Epoch 16/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 27s 543ms/step - accuracy: 1.0000 - loss: 2.0443e-04 - val_accuracy: 0.8796 - val_loss: 0.7653
# Epoch 17/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 40s 515ms/step - accuracy: 1.0000 - loss: 1.6529e-04 - val_accuracy: 0.8803 - val_loss: 0.7843
# Epoch 18/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 25s 516ms/step - accuracy: 1.0000 - loss: 1.5728e-04 - val_accuracy: 0.8805 - val_loss: 0.7943
# Epoch 19/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 25s 517ms/step - accuracy: 1.0000 - loss: 1.1750e-04 - val_accuracy: 0.8800 - val_loss: 0.8090
# Epoch 20/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 46s 606ms/step - accuracy: 1.0000 - loss: 1.1188e-04 - val_accuracy: 0.8805 - val_loss: 0.8173
# Epoch 21/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 28s 563ms/step - accuracy: 1.0000 - loss: 8.5003e-05 - val_accuracy: 0.8807 - val_loss: 0.8291
# Epoch 22/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 39s 518ms/step - accuracy: 1.0000 - loss: 8.1530e-05 - val_accuracy: 0.8803 - val_loss: 0.8390
# Epoch 23/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 26s 522ms/step - accuracy: 1.0000 - loss: 6.6525e-05 - val_accuracy: 0.8800 - val_loss: 0.8455
# Epoch 24/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 25s 519ms/step - accuracy: 1.0000 - loss: 6.2157e-05 - val_accuracy: 0.8800 - val_loss: 0.8548
# Epoch 25/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 27s 558ms/step - accuracy: 1.0000 - loss: 6.1211e-05 - val_accuracy: 0.8801 - val_loss: 0.8598
# Epoch 26/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 32s 652ms/step - accuracy: 1.0000 - loss: 5.9687e-05 - val_accuracy: 0.8798 - val_loss: 0.8669
# Epoch 27/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 27s 552ms/step - accuracy: 1.0000 - loss: 5.4987e-05 - val_accuracy: 0.8802 - val_loss: 0.8720
# Epoch 28/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 28s 574ms/step - accuracy: 1.0000 - loss: 4.7404e-05 - val_accuracy: 0.8804 - val_loss: 0.8770
# Epoch 29/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 40s 553ms/step - accuracy: 1.0000 - loss: 4.5034e-05 - val_accuracy: 0.8800 - val_loss: 0.8831
# Epoch 30/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 548ms/step - accuracy: 1.0000 - loss: 4.2862e-05 - val_accuracy: 0.8799 - val_loss: 0.8882

# %%
b_history_dict = b_model_history.history

b_loss = b_history_dict['loss']
b_val_loss = b_history_dict['val_loss']
epochs = range(1, len(b_loss) + 1)

fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, b_loss, 'b-', label='train_loss(large)')
ax1.plot(epochs, b_val_loss, 'r-', label='val_loss(large)')
ax1.plot(epochs, loss, 'b--', label='train_loss')
ax1.plot(epochs, val_loss, 'r--', label='val_loss')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

b_accuracy = b_history_dict['accuracy']
b_val_accuracy = b_history_dict['val_accuracy']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, b_accuracy, 'b-', label='train_accuracy(large)')
ax2.plot(epochs, b_val_accuracy, 'r-', label='val_accuracy(large)')
ax2.plot(epochs, accuracy, 'b--', label='train_accuracy')
ax2.plot(epochs, val_accuracy, 'r--', label='val_accuracy')
ax2.set_title('Train and Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()

# %% [markdown]
# 결과를 보면, 모델의 크기가 클수록 즉 파라미터 수가 많은 신경망일수록 빠르게 훈련 데이터 모델링이 가능하고 학습 손실이 낮아지는 것을 알 수 있습니다.
# 그러나 모델이 과대적합에는 더욱 민감해지는 것을 학습-검증 데이터 손실을 통해 확인이 가능합니다.

# %% [markdown]
# ### 모델 크기 감소
# * 이제 모델에서 사용한 Dense 레이어의 유닛수를 128대신 16으로 줄여서 사용 해보기
# * 모델의 크기를 줄여서 전체 파라미터의 수가 160,305개로 줄어들게 됩니다.

# %%
s_model = models.Sequential()
s_model.add(layers.Dense(16, activation='relu', input_shape=(10000, ), name='input2')) # 16으로 설정
s_model.add(layers.Dense(16, activation='relu', name='hidden2'))
s_model.add(layers.Dense(1, activation='sigmoid', name='output2'))
s_model.compile(optimizer='rmsprop',
                loss='binary_crossentropy',
                metrics=['accuracy'])
s_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input2 (Dense)                  │ (None, 16)             │       160,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden2 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output2 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 160,305 (626.19 KB)
#  Trainable params: 160,305 (626.19 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
s_model_history = s_model.fit(x_train, y_train,
                              epochs=30,
                              batch_size=512, 
                              validation_data=(x_test, y_test))
# Out:
# Epoch 1/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 305ms/step - accuracy: 0.7366 - loss: 0.5652 - val_accuracy: 0.8805 - val_loss: 0.3520
# Epoch 2/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9048 - loss: 0.2909 - val_accuracy: 0.8901 - val_loss: 0.2870
# Epoch 3/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9226 - loss: 0.2207 - val_accuracy: 0.8853 - val_loss: 0.2857
# Epoch 4/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9391 - loss: 0.1777 - val_accuracy: 0.8862 - val_loss: 0.2843
# Epoch 5/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9478 - loss: 0.1574 - val_accuracy: 0.8790 - val_loss: 0.3055
# Epoch 6/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9503 - loss: 0.1388 - val_accuracy: 0.8794 - val_loss: 0.3104
# Epoch 7/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9619 - loss: 0.1220 - val_accuracy: 0.8765 - val_loss: 0.3296
# Epoch 8/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9652 - loss: 0.1087 - val_accuracy: 0.8727 - val_loss: 0.3560
# Epoch 9/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9675 - loss: 0.0970 - val_accuracy: 0.8725 - val_loss: 0.3681
# Epoch 10/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9759 - loss: 0.0831 - val_accuracy: 0.8657 - val_loss: 0.4040
# Epoch 11/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9788 - loss: 0.0742 - val_accuracy: 0.8661 - val_loss: 0.4142
# Epoch 12/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9820 - loss: 0.0665 - val_accuracy: 0.8570 - val_loss: 0.4781
# Epoch 13/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9852 - loss: 0.0576 - val_accuracy: 0.8639 - val_loss: 0.4637
# Epoch 14/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9884 - loss: 0.0478 - val_accuracy: 0.8635 - val_loss: 0.4844
# Epoch 15/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9906 - loss: 0.0425 - val_accuracy: 0.8607 - val_loss: 0.5106
# Epoch 16/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9932 - loss: 0.0334 - val_accuracy: 0.8592 - val_loss: 0.5369
# Epoch 17/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9935 - loss: 0.0292 - val_accuracy: 0.8556 - val_loss: 0.5927
# Epoch 18/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9957 - loss: 0.0234 - val_accuracy: 0.8543 - val_loss: 0.6235
# Epoch 19/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9957 - loss: 0.0222 - val_accuracy: 0.8328 - val_loss: 0.8396
# Epoch 20/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9945 - loss: 0.0202 - val_accuracy: 0.8584 - val_loss: 0.6392
# Epoch 21/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9981 - loss: 0.0124 - val_accuracy: 0.8573 - val_loss: 0.6752
# Epoch 22/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9981 - loss: 0.0111 - val_accuracy: 0.8561 - val_loss: 0.7064
# Epoch 23/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9981 - loss: 0.0103 - val_accuracy: 0.8472 - val_loss: 0.7754
# Epoch 24/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9965 - loss: 0.0138 - val_accuracy: 0.8570 - val_loss: 0.7385
# Epoch 25/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9990 - loss: 0.0060 - val_accuracy: 0.8578 - val_loss: 0.7522
# Epoch 26/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9998 - loss: 0.0042 - val_accuracy: 0.8586 - val_loss: 0.7669
# Epoch 27/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9993 - loss: 0.0042 - val_accuracy: 0.8566 - val_loss: 0.7953
# Epoch 28/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9997 - loss: 0.0028 - val_accuracy: 0.8567 - val_loss: 0.8125
# Epoch 29/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9998 - loss: 0.0024 - val_accuracy: 0.8577 - val_loss: 0.8404
# Epoch 30/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9981 - loss: 0.0062 - val_accuracy: 0.8574 - val_loss: 0.8578

# %%
s_history_dict = s_model_history.history

s_loss = s_history_dict['loss']
s_val_loss = s_history_dict['val_loss']
epochs = range(1, len(s_loss) + 1)

fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, b_loss, 'b-', label='train_loss(large)')
ax1.plot(epochs, b_val_loss, 'r-', label='val_loss(large)')
ax1.plot(epochs, loss, 'b--', label='train_loss')
ax1.plot(epochs, val_loss, 'r--', label='val_loss')
ax1.plot(epochs, s_loss, 'b:', label='train_loss(small)')
ax1.plot(epochs, s_val_loss, 'r:', label='val_loss(small)')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

s_accuracy = s_history_dict['accuracy']
s_val_accuracy = s_history_dict['val_accuracy']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, b_accuracy, 'b-', label='train_accuracy(large)')
ax2.plot(epochs, b_val_accuracy, 'r-', label='val_accuracy(large)')
ax2.plot(epochs, accuracy, 'b--', label='train_accuracy')
ax2.plot(epochs, val_accuracy, 'r--', label='val_accuracy')
ax2.plot(epochs, s_accuracy, 'b:', label='train_accuracy(small)')
ax2.plot(epochs, s_val_accuracy, 'r:', label='val_accuracy(small)')
ax2.set_title('Train and Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()

# %% [markdown]
# 모델의 크기를 줄였더니 과대적합 문제에 조금 덜 민감한 것을 알 수 있습니다.
# 즉, 모델의 최적화를 위해서는 **파라미터 수를 적절하게 조절 해야 된다는 것**을 알 수 있습니다.
#
# 그렇다면 어느정도 파라미터가 적절할까요? 아래 코드를 이용해 여러분이 조절해보시기 바랍니다.
#
# 단, 그래프는 다른 그래프의 데이터와 구분을 위해 파랑-빨강이 아닌 초록색으로 변경했습니다.
# 초록색 실선이 train 데이터이며 초록색 점선이 validation 데이터입니다.

# %% [markdown]
# ### 직접 설정해보기

# %%
# [play ground]
# 원하는 분은 Dense층을 늘리거나 줄이는 등 모델의 구조 역시 변경해보시기 바랍니다.

your_model = models.Sequential()
your_model.add(layers.Dense(25, activation='relu', input_shape=(10000, ), name='input2'))  #조절해보기
your_model.add(layers.Dense(25, activation='relu', name='hidden2'))                        #조절해보기
your_model.add(layers.Dense(1, activation='sigmoid', name='output2'))
your_model.compile(optimizer='rmsprop',
                loss='binary_crossentropy',
                metrics=['accuracy'])
your_model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input2 (Dense)                  │ (None, 25)             │       250,025 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden2 (Dense)                 │ (None, 25)             │           650 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output2 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 250,701 (979.30 KB)
#  Trainable params: 250,701 (979.30 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
your_model_history = your_model.fit(x_train, 
                                    y_train, 
                                    epochs=15,     # 조절해보기
                                    batch_size=512,  
                                    validation_data=(x_test, y_test))
# Out:
# Epoch 1/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 292ms/step - accuracy: 0.7369 - loss: 0.5426 - val_accuracy: 0.8753 - val_loss: 0.3293
# Epoch 2/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9018 - loss: 0.2700 - val_accuracy: 0.8705 - val_loss: 0.3150
# Epoch 3/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9208 - loss: 0.2130 - val_accuracy: 0.8887 - val_loss: 0.2790
# Epoch 4/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9383 - loss: 0.1722 - val_accuracy: 0.8806 - val_loss: 0.2994
# Epoch 5/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9461 - loss: 0.1550 - val_accuracy: 0.8712 - val_loss: 0.3343
# Epoch 6/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9538 - loss: 0.1362 - val_accuracy: 0.8771 - val_loss: 0.3239
# Epoch 7/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9591 - loss: 0.1202 - val_accuracy: 0.8613 - val_loss: 0.3929
# Epoch 8/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9597 - loss: 0.1159 - val_accuracy: 0.8738 - val_loss: 0.3644
# Epoch 9/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9682 - loss: 0.0949 - val_accuracy: 0.8711 - val_loss: 0.3847
# Epoch 10/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9725 - loss: 0.0858 - val_accuracy: 0.8695 - val_loss: 0.4074
# Epoch 11/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9735 - loss: 0.0800 - val_accuracy: 0.8670 - val_loss: 0.4296
# Epoch 12/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9783 - loss: 0.0704 - val_accuracy: 0.8638 - val_loss: 0.4669
# Epoch 13/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9815 - loss: 0.0620 - val_accuracy: 0.8632 - val_loss: 0.4898
# Epoch 14/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9849 - loss: 0.0523 - val_accuracy: 0.8596 - val_loss: 0.5128
# Epoch 15/15
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9880 - loss: 0.0447 - val_accuracy: 0.8583 - val_loss: 0.5439

# %%
your_history_dict = your_model_history.history

your_loss = your_history_dict['loss']
your_val_loss = your_history_dict['val_loss']
epochs = range(1, len(your_loss) + 1)

fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, b_loss, 'b-', label='train_loss(large)')
ax1.plot(epochs, b_val_loss, 'r-', label='val_loss(large)')
ax1.plot(epochs, loss, 'b--', label='train_loss')
ax1.plot(epochs, val_loss, 'r--', label='val_loss')
ax1.plot(epochs, your_loss, 'b:', label='train_loss(small)')
ax1.plot(epochs, your_val_loss, 'r:', label='val_loss(small)')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

your_accuracy = your_history_dict['accuracy']
your_val_accuracy = your_history_dict['val_accuracy']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, b_accuracy, 'b-', label='train_accuracy(large)')
ax2.plot(epochs, b_val_accuracy, 'r-', label='val_accuracy(large)')
ax2.plot(epochs, accuracy, 'b--', label='train_accuracy')
ax2.plot(epochs, val_accuracy, 'r--', label='val_accuracy')
ax2.plot(epochs, s_accuracy, 'b:', label='train_accuracy(small)')
ax2.plot(epochs, s_val_accuracy, 'r:', label='val_accuracy(small)')
ax2.plot(epochs, your_accuracy, 'g-', label='train_accuracy(your)')
ax2.plot(epochs, your_val_accuracy, 'g--', label='val_accuracy(your)')
ax2.set_title('Train and Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 10
#       7 fig = plt.figure(figsize=(12, 5))
#       9 ax1 = fig.add_subplot(1, 2, 1)
# ---> 10 ax1.plot(epochs, b_loss, 'b-', label='train_loss(large)')
#      11 ax1.plot(epochs, b_val_loss, 'r-', label='val_loss(large)')
#      12 ax1.plot(epochs, loss, 'b--', label='train_loss')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:1779, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1536 """
#    1537 Plot y versus x as lines and/or markers.
#    1538
#    (...)
#    1776 (``'green'``) or hex strings (``'#008000'``).
#    1777 """
#    1778 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1779 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1780 for line in lines:
#    1781     self.add_line(line)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:296, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     294     this += args[0],
#     295     args = args[1:]
# --> 296 yield from self._plot_args(
#     297     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:486, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     483     axes.yaxis.update_units(y)
#     485 if x.shape[0] != y.shape[0]:
# --> 486     raise ValueError(f"x and y must have same first dimension, but "
#     487                      f"have shapes {x.shape} and {y.shape}")
#     488 if x.ndim > 2 or y.ndim > 2:
#     489     raise ValueError(f"x and y can be no greater than 2D, but have "
#     490                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (15,) and (30,)

# %% [markdown]
# # 02 규제

# %% [markdown]
# * 모델의 과대적합을 방지하는 방법 중에 하나로 규제가 있다.
# * 가중치의 파라미터 값이 커서 과대적합이 발생하는 경우가 많기 때문에 이를 방지하기 위해 큰 가중치 값은 큰 규제를 가하는 방법이 규제화이다.
# * 규제를 통해 가중치의 절댓값을 가능한 작게 만들어서 가중치의 모든 원소를 0에 가깝게 하여 모든 특성이 출력에 주는 영향을 최소한으로 만드는 것을 의미
# * 즉, 기울기를 작게 만드는 과정
# * 규제를 통해서 가중치의 분포가 더 균일하게 되고, 복잡한 네트워크일수록 네트워크의 복잡도에 제한을 두어 가중치가 작은 값을 가지도록 한다.
# * 규제가 모델이 과대적합 되지 않도록 강제로 제한하는 역할을 하므로 적절한 규제값을 찾는 것이 중요하다
# * 모델의 손실함수에서 큰 가중치에 비용을 추가하는 형태로 규제를 적용할 수 있으며 대표적인 방법으로 L1 규제와 L2 규제가 있다.
# * L1 규제는 가중치의 절댓값에 비례하는 비용이 추가되고, L2 규제는 가중치 감쇠(weight decay)라고도 불리며,
#   가중치의 제곱에 비례하는 비용이 추가됩니다. 또한, **L1과 L2를 둘다 합쳐서 사용하는 경우도 존재**
#
# ![image.png](attachment:af54d68e-64d2-4ac4-8107-79c92f852518.png)

# %% [markdown]
# ## L1 규제 (L1 Regularization)
#
# - L1 규제는 가중치의 절댓값 합에 비례하는 비용을 손실 함수에 추가하는 방법
# - 가중치의 절댓값은 L1 노름(norm)이라고 하며 다음과 같이 표현  $$  ||w||_1 = \sum_{i=1}^{n} |w_i|  $$
# - 기존의 손실 함수 \( L \)에서 \( \alpha \)를 곱한 L1 규제를 적용하여 계산  $$  \frac{1}{n} \sum_{i=1}^{n} L(y_i, \hat{y}_i) + \alpha \sum_{j=1}^{m} |w_j|$$
# - $ \alpha $ 값을 이용하여 사용자가 하이퍼파라미터처럼 규제의 조절이 가능
# - $ \alpha $ 값을 증가시키면 규제가 강화되어 가중치 절댓값의 합을 줄이도록 학습하여
#   가중치가 0인 중요하지 않은 변수를 제외되어 일반화에 적합
# - $ \alpha $ 값을 감소시키면 규제가 약해져서 가중치 값이 증가하고 과대적합이 발생할 수 있음

# %% [markdown]
# ### L1 규제 적용하기
# 1. 케라스에서 L1 규제를 사용하기 위해서는 적용할 레이어에서 kernel_regularizer를 l1으로 지정해주면 됩니다.
# 2. 물론 레이어에 bias_regularizer와 activity_regularizer에도 적용할 수 있습니다.
# 3. 케라스에서 L1 규제를 사용하기 위해서는 적용할 레이어에서 가중치 정규화인 kernel_regularizer를 l1으로 지정해주면 됩니다.
# 4. 물론 레이어에 편향 정규화인 bias_regularizer와 출력값 정규화인 activity_regularizer에도 적용할 수 있습니다.

# %%
l1_model =  models.Sequential()

l1_model.add(layers.Dense(16,
                          kernel_regularizer='l1',
                          activation='relu',
                          input_shape=(10000, )))
l1_model.add(layers.Dense(16,
                          kernel_regularizer='l1',
                          activation='relu'))
l1_model.add(layers.Dense(1, activation='sigmoid'))
l1_model.compile(optimizer='rmsprop',
                 loss='binary_crossentropy',
                 metrics=['accuracy'])

l1_model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │       160,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 160,305 (626.19 KB)
#  Trainable params: 160,305 (626.19 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
l1_model_hist = l1_model.fit(x_train, y_train,
                             epochs=30,
                             batch_size=512,
                             validation_data=(x_test, y_test))
# Out:
# Epoch 1/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 23s 402ms/step - accuracy: 0.5610 - loss: 7.1248 - val_accuracy: 0.5474 - val_loss: 1.9002
# Epoch 2/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.6488 - loss: 1.8574 - val_accuracy: 0.6138 - val_loss: 1.7744
# Epoch 3/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.6993 - loss: 1.7518 - val_accuracy: 0.6604 - val_loss: 1.6961
# Epoch 4/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7167 - loss: 1.6675 - val_accuracy: 0.7293 - val_loss: 1.6080
# Epoch 5/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.7264 - loss: 1.5978 - val_accuracy: 0.7580 - val_loss: 1.5542
# Epoch 6/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.7591 - loss: 1.5322 - val_accuracy: 0.7744 - val_loss: 1.4880
# Epoch 7/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.7800 - loss: 1.4787 - val_accuracy: 0.7873 - val_loss: 1.4506
# Epoch 8/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.7953 - loss: 1.4375 - val_accuracy: 0.7981 - val_loss: 1.4120
# Epoch 9/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.7974 - loss: 1.4122 - val_accuracy: 0.8036 - val_loss: 1.4094
# Epoch 10/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8116 - loss: 1.3928 - val_accuracy: 0.8121 - val_loss: 1.3863
# Epoch 11/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.8170 - loss: 1.3842 - val_accuracy: 0.8196 - val_loss: 1.3866
# Epoch 12/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8254 - loss: 1.3739 - val_accuracy: 0.8183 - val_loss: 1.3770
# Epoch 13/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8293 - loss: 1.3683 - val_accuracy: 0.8250 - val_loss: 1.3777
# Epoch 14/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8320 - loss: 1.3590 - val_accuracy: 0.8288 - val_loss: 1.3600
# Epoch 15/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8356 - loss: 1.3538 - val_accuracy: 0.8358 - val_loss: 1.3618
# Epoch 16/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8372 - loss: 1.3538 - val_accuracy: 0.8371 - val_loss: 1.3431
# Epoch 17/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8381 - loss: 1.3452 - val_accuracy: 0.8230 - val_loss: 1.3798
# Epoch 18/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8441 - loss: 1.3370 - val_accuracy: 0.8416 - val_loss: 1.3356
# Epoch 19/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8444 - loss: 1.3356 - val_accuracy: 0.8410 - val_loss: 1.3470
# Epoch 20/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8424 - loss: 1.3338 - val_accuracy: 0.8425 - val_loss: 1.3317
# Epoch 21/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.8489 - loss: 1.3240 - val_accuracy: 0.8467 - val_loss: 1.3330
# Epoch 22/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8536 - loss: 1.3204 - val_accuracy: 0.8465 - val_loss: 1.3216
# Epoch 23/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8480 - loss: 1.3233 - val_accuracy: 0.8414 - val_loss: 1.3391
# Epoch 24/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8510 - loss: 1.3172 - val_accuracy: 0.8432 - val_loss: 1.3260
# Epoch 25/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8506 - loss: 1.3168 - val_accuracy: 0.8512 - val_loss: 1.3230
# Epoch 26/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8530 - loss: 1.3140 - val_accuracy: 0.8520 - val_loss: 1.3110
# Epoch 27/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8559 - loss: 1.3126 - val_accuracy: 0.8446 - val_loss: 1.3339
# Epoch 28/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8550 - loss: 1.3087 - val_accuracy: 0.8214 - val_loss: 1.3578
# Epoch 29/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.8519 - loss: 1.3113 - val_accuracy: 0.8493 - val_loss: 1.3224
# Epoch 30/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8512 - loss: 1.3108 - val_accuracy: 0.8418 - val_loss: 1.3229

# %%
l1_val_loss = l1_model_hist.history['val_loss']

epochs = range(1, 31)
plt.plot(epochs, val_loss, 'k--', label='Model')
plt.plot(epochs, l1_val_loss, 'b--', label='L1-regularized')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# 기존 모델의 결과와 L1 규제를 사용한 결과를 비교해보면, 기존 모델은 Loss 값이 점점 증가하며 과대적합의 모습을 보이는 반면,
# L1 규제 결과는 안정적으로 Loss 값이 감소되는 것을 알 수 있습니다.

# %% [markdown]
# ---

# %% [markdown]
# ## L2 규제 (L2 Regularization)
#
# * L2 규제는 가중치 감쇠(weight decay)라고도 불리며, 가중치의 제곱에 비례하는 비용을 손실 함수의 일정 값에 더하는 방법
# * 가중치의 제곱은 L2 노름(norm)이라고 하며 다음과 같이 표현 $$  ||w||_2 = \sqrt{\sum_{i=1}^{n} w_i^2}  $$
# * 기존의 손실 함수 \( L \)에서 \( \lambda \)를 곱한 L2 규제를 적용하여 계산 $$  \frac{1}{n} \sum_{i=1}^{n} L(y_i, \hat{y}_i) + \lambda \sum_{j=1}^{m} w_j^2  $$
# * L2 규제는 가중치의 제곱에 비례하는 비용을 손실 함수의 일정 값을 더하여 과대적합을 방지
# * \( \lambda \) 값이 크면 가중치 감소가 커지고, 작으면 가하는 규제가 적어지게 됨
# * L2 규제는 L1보다 더 Robust한 모델을 생성하므로 많이 사용되는 방법 중 하나

# %% [markdown]
# ### L2 적용하기
# 케라스에서 L2 규제를 사용하기 위해서는 적용할 레이어에서 kernel_regularizer를 l2로 지정해주면 됩니다.

# %%
l2_model =  models.Sequential()
l2_model.add(layers.Dense(16,
                          kernel_regularizer='l2',
                          activation='relu',
                          input_shape=(10000, )))
l2_model.add(layers.Dense(16,
                          kernel_regularizer='l2',
                          activation='relu'))
l2_model.add(layers.Dense(1, activation='sigmoid'))
l2_model.compile(optimizer='rmsprop',
                 loss='binary_crossentropy',
                 metrics=['accuracy'])
l2_model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 16)             │       160,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 160,305 (626.19 KB)
#  Trainable params: 160,305 (626.19 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
l2_model_hist = l2_model.fit(x_train, y_train,
                             epochs=30,
                             batch_size=512,
                             validation_data=(x_test, y_test))
# Out:
# Epoch 1/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 16s 260ms/step - accuracy: 0.7137 - loss: 0.9110 - val_accuracy: 0.8483 - val_loss: 0.6121
# Epoch 2/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8819 - loss: 0.5614 - val_accuracy: 0.8582 - val_loss: 0.5463
# Epoch 3/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8872 - loss: 0.4976 - val_accuracy: 0.8713 - val_loss: 0.5003
# Epoch 4/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8910 - loss: 0.4609 - val_accuracy: 0.8781 - val_loss: 0.4729
# Epoch 5/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8974 - loss: 0.4365 - val_accuracy: 0.8612 - val_loss: 0.4864
# Epoch 6/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.8969 - loss: 0.4220 - val_accuracy: 0.8826 - val_loss: 0.4425
# Epoch 7/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8983 - loss: 0.4117 - val_accuracy: 0.8557 - val_loss: 0.4784
# Epoch 8/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8976 - loss: 0.4086 - val_accuracy: 0.8828 - val_loss: 0.4322
# Epoch 9/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.9020 - loss: 0.3964 - val_accuracy: 0.8803 - val_loss: 0.4306
# Epoch 10/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9048 - loss: 0.3883 - val_accuracy: 0.8825 - val_loss: 0.4232
# Epoch 11/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9070 - loss: 0.3816 - val_accuracy: 0.8693 - val_loss: 0.4426
# Epoch 12/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9031 - loss: 0.3817 - val_accuracy: 0.8846 - val_loss: 0.4172
# Epoch 13/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9059 - loss: 0.3760 - val_accuracy: 0.8846 - val_loss: 0.4159
# Epoch 14/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9101 - loss: 0.3721 - val_accuracy: 0.8786 - val_loss: 0.4229
# Epoch 15/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9116 - loss: 0.3658 - val_accuracy: 0.8794 - val_loss: 0.4175
# Epoch 16/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9125 - loss: 0.3620 - val_accuracy: 0.8838 - val_loss: 0.4083
# Epoch 17/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9137 - loss: 0.3560 - val_accuracy: 0.8824 - val_loss: 0.4103
# Epoch 18/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9079 - loss: 0.3615 - val_accuracy: 0.8629 - val_loss: 0.4458
# Epoch 19/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9067 - loss: 0.3614 - val_accuracy: 0.8710 - val_loss: 0.4257
# Epoch 20/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9061 - loss: 0.3616 - val_accuracy: 0.8799 - val_loss: 0.4105
# Epoch 21/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9134 - loss: 0.3494 - val_accuracy: 0.8841 - val_loss: 0.4000
# Epoch 22/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9150 - loss: 0.3417 - val_accuracy: 0.8814 - val_loss: 0.4028
# Epoch 23/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9132 - loss: 0.3446 - val_accuracy: 0.8809 - val_loss: 0.4057
# Epoch 24/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9188 - loss: 0.3410 - val_accuracy: 0.8674 - val_loss: 0.4286
# Epoch 25/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9090 - loss: 0.3519 - val_accuracy: 0.8733 - val_loss: 0.4167
# Epoch 26/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9159 - loss: 0.3399 - val_accuracy: 0.8831 - val_loss: 0.3962
# Epoch 27/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9197 - loss: 0.3327 - val_accuracy: 0.8835 - val_loss: 0.3957
# Epoch 28/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9128 - loss: 0.3398 - val_accuracy: 0.8833 - val_loss: 0.3948
# Epoch 29/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - accuracy: 0.9190 - loss: 0.3283 - val_accuracy: 0.8667 - val_loss: 0.4229
# Epoch 30/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9194 - loss: 0.3275 - val_accuracy: 0.8624 - val_loss: 0.4351

# %%
l2_val_loss = l2_model_hist.history['val_loss']

epochs = range(1, 31)
plt.plot(epochs, val_loss, 'k--', label='Model')
plt.plot(epochs, l2_val_loss, 'r--', label='L2-regularized')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## L1 L2 규제
# L1과 L2 규제를 같이 적용하는 방법도 존재하는데, 케라스에서 L1과 L2 규제를 같이 사용하기 위해서는
# 적용할 레이어에서 kernel_regularizer를 l1_l2로 지정해주면 됩니다.

# %%
## 업데이트 되면서 아래처럼 진행해주셔야합니다


# l1_l2_model = models.Sequential()
# l1_l2_model.add(layers.Dense(16,
#                              kernel_regularizer='l1_l2',
#                              activation='relu', input_shape=(10000, )))
# l1_l2_model.add(layers.Dense(16,
#                              kernel_regularizer='l1_l2',
#                              activation='relu'))
# l1_l2_model.add(layers.Dense(1, activation='sigmoid'))
# l1_l2_model.compile(optimizer='rmsprop',
#                     loss='binary_crossentropy',
#                     metrics=['accuracy'])
# l1_l2_model.summary()


from tensorflow.keras import models, layers, regularizers

l1_l2_model = models.Sequential()

l1_l2_model.add(layers.Dense(16,
                             kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001),
                             activation='relu',
                             input_shape=(10000,)))
l1_l2_model.add(layers.Dense(16,
                             kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.001),
                             activation='relu'))
l1_l2_model.add(layers.Dense(1, activation='sigmoid'))

l1_l2_model.compile(optimizer='rmsprop',
                    loss='binary_crossentropy',
                    metrics=['accuracy'])

l1_l2_model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 16)             │       160,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 160,305 (626.19 KB)
#  Trainable params: 160,305 (626.19 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
l1_l2_model_hist = l1_l2_model.fit(x_train, y_train,
                                  epochs=30,
                                  batch_size=512,
                                  validation_data=(x_test, y_test))
# Out:
# Epoch 1/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 335ms/step - accuracy: 0.6875 - loss: 1.4173 - val_accuracy: 0.8164 - val_loss: 0.7035
# Epoch 2/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.8296 - loss: 0.6747 - val_accuracy: 0.8096 - val_loss: 0.6754
# Epoch 3/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8425 - loss: 0.6237 - val_accuracy: 0.8563 - val_loss: 0.5933
# Epoch 4/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.8533 - loss: 0.5943 - val_accuracy: 0.8576 - val_loss: 0.5777
# Epoch 5/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8603 - loss: 0.5736 - val_accuracy: 0.8237 - val_loss: 0.6284
# Epoch 6/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.8585 - loss: 0.5702 - val_accuracy: 0.8612 - val_loss: 0.5574
# Epoch 7/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.8583 - loss: 0.5614 - val_accuracy: 0.8632 - val_loss: 0.5526
# Epoch 8/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.8613 - loss: 0.5546 - val_accuracy: 0.8590 - val_loss: 0.5536
# Epoch 9/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8635 - loss: 0.5432 - val_accuracy: 0.8470 - val_loss: 0.5750
# Epoch 10/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.8698 - loss: 0.5412 - val_accuracy: 0.8662 - val_loss: 0.5378
# Epoch 11/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8670 - loss: 0.5325 - val_accuracy: 0.8669 - val_loss: 0.5346
# Epoch 12/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8720 - loss: 0.5241 - val_accuracy: 0.8657 - val_loss: 0.5367
# Epoch 13/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.8659 - loss: 0.5387 - val_accuracy: 0.8644 - val_loss: 0.5308
# Epoch 14/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8726 - loss: 0.5219 - val_accuracy: 0.8658 - val_loss: 0.5322
# Epoch 15/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.8764 - loss: 0.5110 - val_accuracy: 0.8498 - val_loss: 0.5577
# Epoch 16/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8735 - loss: 0.5108 - val_accuracy: 0.8664 - val_loss: 0.5212
# Epoch 17/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8812 - loss: 0.4979 - val_accuracy: 0.8654 - val_loss: 0.5241
# Epoch 18/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8781 - loss: 0.5015 - val_accuracy: 0.8733 - val_loss: 0.5051
# Epoch 19/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8800 - loss: 0.4941 - val_accuracy: 0.8768 - val_loss: 0.5004
# Epoch 20/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8855 - loss: 0.4835 - val_accuracy: 0.8742 - val_loss: 0.5023
# Epoch 21/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8849 - loss: 0.4840 - val_accuracy: 0.8767 - val_loss: 0.4970
# Epoch 22/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.8866 - loss: 0.4776 - val_accuracy: 0.8720 - val_loss: 0.5021
# Epoch 23/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8899 - loss: 0.4717 - val_accuracy: 0.8761 - val_loss: 0.4943
# Epoch 24/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.8914 - loss: 0.4685 - val_accuracy: 0.8792 - val_loss: 0.4849
# Epoch 25/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.8918 - loss: 0.4646 - val_accuracy: 0.8747 - val_loss: 0.4944
# Epoch 26/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8949 - loss: 0.4622 - val_accuracy: 0.8813 - val_loss: 0.4786
# Epoch 27/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.8948 - loss: 0.4562 - val_accuracy: 0.8811 - val_loss: 0.4782
# Epoch 28/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8981 - loss: 0.4493 - val_accuracy: 0.8823 - val_loss: 0.4796
# Epoch 29/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9005 - loss: 0.4473 - val_accuracy: 0.8766 - val_loss: 0.4857
# Epoch 30/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.8987 - loss: 0.4435 - val_accuracy: 0.8788 - val_loss: 0.4783

# %%
l1_l2_val_loss = l1_l2_model_hist.history['val_loss']

epochs = range(1, 31)
plt.plot(epochs, val_loss, 'k--', label='Model')
plt.plot(epochs, l1_l2_val_loss, 'g--', label='L1_L2-regularized')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# L1 L2 규제를 함께 사용하는 경우는 L1 규제와 큰 차이가 없는 것을 알 수 있습니다.

# %%
epochs = range(1, 31)
plt.plot(epochs, val_loss, 'k--', label='Model')
plt.plot(epochs, l1_val_loss, 'b--', label='L1-regularized')
plt.plot(epochs, l2_val_loss, 'r--', label='L2-regularized')
plt.plot(epochs, l1_l2_val_loss, 'g--', label='L1_L2-regularized')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# 전체 규제 방법들을 다 비교해보면, L2 규제가 가장 좋은 결과를 보여주고 있습니다.
# 물론 어떤 모델에 어떤 규제 방법이 좋을지는 실험을 통해 찾아가는 과정이 필요합니다.
#
# 위에서 다양한 종류의 규제를 사용해 보았지만 영상에서도 언급했듯이 큰 규제 값을 줄 수도 있고 작은 규제 값을 줄 수도 있습니다.
# 위에서 실험한 결과 가장 좋아 보인 L2 규제라도 어떤 규제 값을 주느냐에 따라 결과가 달라질 것입니다.
# 이 부분은 여러분이 kernel_regularizaer 부분을 직접 변경해가며 찾아보시죠. 여러분의 val_loss는 노란색으로 표시했습니다.

# %%
# [play ground]
# L2 규제의 기본 값은 0.01입니다. 여러분이 원하는 크기로 조절해보세요. 혹은 다른 규제를 사용하셔도 됩니다.

your_model = models.Sequential()
your_model.add(layers.Dense(20, kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.005)))
your_model.add(layers.Dense(20, kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.005)))
your_model.add(layers.Dense(1, activation='sigmoid'))

your_model.compile(optimizer='rmsprop',
                   loss='binary_crossentropy',
                   metrics=['accuracy'])

your_model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
your_model_hist = your_model.fit(x_train, y_train,
                                 epochs=30,
                                 batch_size=512,
                                 validation_data=(x_test, y_test))
# Out:
# Epoch 1/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 16s 313ms/step - accuracy: 0.8559 - loss: 1.5113 - val_accuracy: 0.8537 - val_loss: 1.5070
# Epoch 2/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.8582 - loss: 1.5070 - val_accuracy: 0.8523 - val_loss: 1.5135
# Epoch 3/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8541 - loss: 1.5091 - val_accuracy: 0.8343 - val_loss: 1.5410
# Epoch 4/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8585 - loss: 1.5060 - val_accuracy: 0.8461 - val_loss: 1.5233
# Epoch 5/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.8554 - loss: 1.5025 - val_accuracy: 0.8536 - val_loss: 1.5087
# Epoch 6/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.8555 - loss: 1.5022 - val_accuracy: 0.8580 - val_loss: 1.4990
# Epoch 7/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.8587 - loss: 1.4958 - val_accuracy: 0.8562 - val_loss: 1.5007
# Epoch 8/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.8602 - loss: 1.4976 - val_accuracy: 0.8460 - val_loss: 1.5186
# Epoch 9/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8590 - loss: 1.4950 - val_accuracy: 0.8512 - val_loss: 1.5102
# Epoch 10/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.8592 - loss: 1.4928 - val_accuracy: 0.8517 - val_loss: 1.5121
# Epoch 11/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8623 - loss: 1.4888 - val_accuracy: 0.8406 - val_loss: 1.5277
# Epoch 12/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.8623 - loss: 1.4893 - val_accuracy: 0.8497 - val_loss: 1.5154
# Epoch 13/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8652 - loss: 1.4843 - val_accuracy: 0.8566 - val_loss: 1.4935
# Epoch 14/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.8551 - loss: 1.4987 - val_accuracy: 0.8454 - val_loss: 1.5233
# Epoch 15/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8616 - loss: 1.4874 - val_accuracy: 0.8611 - val_loss: 1.4872
# Epoch 16/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8584 - loss: 1.4929 - val_accuracy: 0.8563 - val_loss: 1.4956
# Epoch 17/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.8602 - loss: 1.4884 - val_accuracy: 0.8613 - val_loss: 1.4876
# Epoch 18/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.8615 - loss: 1.4893 - val_accuracy: 0.8614 - val_loss: 1.4820
# Epoch 19/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8611 - loss: 1.4879 - val_accuracy: 0.8618 - val_loss: 1.4820
# Epoch 20/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8592 - loss: 1.4891 - val_accuracy: 0.8630 - val_loss: 1.4842
# Epoch 21/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8612 - loss: 1.4834 - val_accuracy: 0.8619 - val_loss: 1.4787
# Epoch 22/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8659 - loss: 1.4796 - val_accuracy: 0.8579 - val_loss: 1.4924
# Epoch 23/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.8625 - loss: 1.4871 - val_accuracy: 0.8610 - val_loss: 1.4849
# Epoch 24/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8647 - loss: 1.4769 - val_accuracy: 0.8572 - val_loss: 1.4854
# Epoch 25/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8631 - loss: 1.4815 - val_accuracy: 0.8592 - val_loss: 1.4878
# Epoch 26/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8653 - loss: 1.4729 - val_accuracy: 0.8615 - val_loss: 1.4807
# Epoch 27/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.8657 - loss: 1.4775 - val_accuracy: 0.8553 - val_loss: 1.4936
# Epoch 28/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8600 - loss: 1.4853 - val_accuracy: 0.8603 - val_loss: 1.4843
# Epoch 29/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8678 - loss: 1.4719 - val_accuracy: 0.8621 - val_loss: 1.4758
# Epoch 30/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8620 - loss: 1.4843 - val_accuracy: 0.8513 - val_loss: 1.4964

# %%
your_val_loss = your_model_hist.history['val_loss']

epochs = range(1, 31)
plt.plot(epochs, val_loss, 'k--', label='Model')
plt.plot(epochs, l1_val_loss, 'b--', label='L1-regularized')
plt.plot(epochs, l2_val_loss, 'r--', label='L2-regularized')
plt.plot(epochs, l1_l2_val_loss, 'g--', label='L1_L2-regularized')
plt.plot(epochs, your_val_loss, 'y--', label='Your L2-regularized')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # 03 드롭아웃 (Dropout)

# %% [markdown]
# * 딥러닝 모델의 과대적합을 방지하기 위한 규제 기법 중 하나로 자주 사용되는 드롭아웃이다.
# * 다른 규제 기법과 달리 드롭아웃은 개념도 쉽고 효과적이며 사용하기도 간편하여 가장 널리 사용되는 방법
# * 드롭아웃은 **모델이 학습할 때 사용하는 노드의 수를 전체 노드 중에서 일부만을 사용** 하는 방법
# * 신경망에 드롭아웃을 적용하면, 학습이 진행되는 동안 무작위로 층(레이어)의 일부 특성(노드)를 제외하는 형태로 동작
# * 일반적으로는 20% ~ 50% 사이의 비율로 지정되어 드롭아웃을 사용
# * 테스트 단계에서는 그 어떤 노드도 드롭아웃 되지 않고, 대신 해당 레이어의 출력 노드를 드롭아웃 비율에 맞게 줄여주게 된다.
#  ![image.png](attachment:557bbf70-5602-43a3-a16b-801425b3024d.png)

# %% [markdown]
# ## 드롭아웃 (20%)
# 드롭아웃이 포함된 딥러닝 모델을 정의하기 위해 기존 모델에서 사용한 구조에서 적절한 위치에 드롭아웃 레이어를 추가해야 합니다.
# 먼저 첫번째 레이어와 두번째 레이어 사이에 Dropout 레이어를 추가하는데, 20% 정도만 적용하기 위해서 0.2로 지정해줍니다.
# 마찬가지로 기존 두번째 레이어와 세번째 레이어 사이에 20%로 적용한 Dropout 레이어를 추가합니다.

# %%
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000, )))
model.add(layers.Dropout(0.2))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dropout(0.2))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                │ (None, 16)             │       160,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 160,305 (626.19 KB)
#  Trainable params: 160,305 (626.19 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#기존 모델과 어떤 차이가 나는지 비교하기 위해 학습 히스토리를 별도로 저장합니다.
drop_20_history = model.fit(x_train, y_train,
                            epochs=30,
                            batch_size=512,
                            validation_data=(x_test, y_test))
# Out:
# Epoch 1/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 23s 431ms/step - accuracy: 0.6960 - loss: 0.5882 - val_accuracy: 0.8726 - val_loss: 0.3676
# Epoch 2/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8786 - loss: 0.3435 - val_accuracy: 0.8874 - val_loss: 0.2900
# Epoch 3/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9084 - loss: 0.2580 - val_accuracy: 0.8830 - val_loss: 0.2911
# Epoch 4/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9265 - loss: 0.2118 - val_accuracy: 0.8873 - val_loss: 0.2793
# Epoch 5/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9392 - loss: 0.1791 - val_accuracy: 0.8862 - val_loss: 0.2897
# Epoch 6/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9519 - loss: 0.1478 - val_accuracy: 0.8839 - val_loss: 0.3034
# Epoch 7/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9597 - loss: 0.1262 - val_accuracy: 0.8766 - val_loss: 0.3313
# Epoch 8/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9653 - loss: 0.1074 - val_accuracy: 0.8735 - val_loss: 0.3759
# Epoch 9/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9713 - loss: 0.0935 - val_accuracy: 0.8742 - val_loss: 0.3821
# Epoch 10/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9760 - loss: 0.0806 - val_accuracy: 0.8752 - val_loss: 0.4122
# Epoch 11/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9772 - loss: 0.0699 - val_accuracy: 0.8742 - val_loss: 0.4498
# Epoch 12/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9833 - loss: 0.0556 - val_accuracy: 0.8724 - val_loss: 0.4736
# Epoch 13/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9865 - loss: 0.0456 - val_accuracy: 0.8667 - val_loss: 0.5218
# Epoch 14/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9883 - loss: 0.0398 - val_accuracy: 0.8690 - val_loss: 0.5348
# Epoch 15/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9889 - loss: 0.0361 - val_accuracy: 0.8633 - val_loss: 0.6329
# Epoch 16/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9914 - loss: 0.0297 - val_accuracy: 0.8700 - val_loss: 0.6162
# Epoch 17/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9920 - loss: 0.0270 - val_accuracy: 0.8681 - val_loss: 0.6309
# Epoch 18/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9924 - loss: 0.0242 - val_accuracy: 0.8674 - val_loss: 0.6735
# Epoch 19/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9930 - loss: 0.0223 - val_accuracy: 0.8677 - val_loss: 0.7158
# Epoch 20/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9942 - loss: 0.0187 - val_accuracy: 0.8662 - val_loss: 0.7520
# Epoch 21/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9939 - loss: 0.0192 - val_accuracy: 0.8670 - val_loss: 0.8315
# Epoch 22/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9935 - loss: 0.0183 - val_accuracy: 0.8674 - val_loss: 0.7717
# Epoch 23/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9940 - loss: 0.0168 - val_accuracy: 0.8672 - val_loss: 0.8584
# Epoch 24/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9956 - loss: 0.0141 - val_accuracy: 0.8649 - val_loss: 0.8628
# Epoch 25/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9954 - loss: 0.0147 - val_accuracy: 0.8689 - val_loss: 0.8969
# Epoch 26/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9938 - loss: 0.0166 - val_accuracy: 0.8676 - val_loss: 0.9102
# Epoch 27/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9956 - loss: 0.0124 - val_accuracy: 0.8660 - val_loss: 0.9800
# Epoch 28/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9954 - loss: 0.0164 - val_accuracy: 0.8677 - val_loss: 0.9643
# Epoch 29/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9956 - loss: 0.0135 - val_accuracy: 0.8645 - val_loss: 0.9657
# Epoch 30/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9948 - loss: 0.0148 - val_accuracy: 0.8690 - val_loss: 0.9876

# %%
#기존 모델의 히스토리 결과와 드롭아웃을 20% 적용한 히스토리 결과를 각각 비교하기 위해 차트로 시각화합니다.
drop_20_dict = drop_20_history.history

drop_20_loss = drop_20_dict['loss']
drop_20_val_loss = drop_20_dict['val_loss']
epochs = range(1, len(loss) + 1)

fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, 'b-', label='train_loss')
ax1.plot(epochs, val_loss, 'r-', label='val_loss')
ax1.plot(epochs, drop_20_loss, 'b--', label='train_loss (dropout 20%)')
ax1.plot(epochs, drop_20_val_loss, 'r--', label='val_loss (dropout 20%)')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

drop_20_accuracy = drop_20_dict['accuracy']
drop_20_val_accuracy = drop_20_dict['val_accuracy']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, accuracy, 'b-', label='train_accuracy')
ax2.plot(epochs, val_accuracy, 'r-', label='val_accuracy')
ax2.plot(epochs, drop_20_accuracy, 'b--', label='train_accuracy (dropout 20%)')
ax2.plot(epochs, drop_20_val_accuracy, 'r--', label='val_accuracy (dropout 20%)')
ax2.set_title('Train and Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()

# %% [markdown]
# 차트를 보면 기존 모델과 비교하여 드롭아웃을 적용한 모델이 과대적합 정도가 감소한 것을 알 수 있습니다.

# %% [markdown]
# ## 드롭아웃 (50%)
# 기존 모델보다 드롭아웃 비중을 50%로 증가시키기 위해 Dropout 레이어에서 0.2로 지정된 값을 0.5로 증가시켜 줍니다.

# %%
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000, )))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_15 (Dense)                │ (None, 16)             │       160,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 160,305 (626.19 KB)
#  Trainable params: 160,305 (626.19 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# 마찬가지로 모델별로 비교를 위해서 학습 히스토리를 별도로 저장합니다.
drop_50_history = model.fit(x_train, y_train,
                            epochs=30,
                            batch_size=512,
                            validation_data=(x_test, y_test))
# Out:
# Epoch 1/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 286ms/step - accuracy: 0.6087 - loss: 0.6508 - val_accuracy: 0.8598 - val_loss: 0.4815
# Epoch 2/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7884 - loss: 0.4917 - val_accuracy: 0.8780 - val_loss: 0.3558
# Epoch 3/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.8444 - loss: 0.3875 - val_accuracy: 0.8856 - val_loss: 0.2993
# Epoch 4/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8773 - loss: 0.3368 - val_accuracy: 0.8880 - val_loss: 0.2810
# Epoch 5/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9017 - loss: 0.2852 - val_accuracy: 0.8897 - val_loss: 0.2772
# Epoch 6/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9163 - loss: 0.2479 - val_accuracy: 0.8855 - val_loss: 0.2852
# Epoch 7/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9268 - loss: 0.2223 - val_accuracy: 0.8880 - val_loss: 0.2891
# Epoch 8/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9340 - loss: 0.2004 - val_accuracy: 0.8867 - val_loss: 0.3100
# Epoch 9/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9434 - loss: 0.1850 - val_accuracy: 0.8864 - val_loss: 0.3223
# Epoch 10/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9452 - loss: 0.1708 - val_accuracy: 0.8844 - val_loss: 0.3225
# Epoch 11/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9512 - loss: 0.1518 - val_accuracy: 0.8832 - val_loss: 0.3641
# Epoch 12/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9534 - loss: 0.1501 - val_accuracy: 0.8827 - val_loss: 0.3917
# Epoch 13/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9554 - loss: 0.1341 - val_accuracy: 0.8802 - val_loss: 0.4041
# Epoch 14/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9571 - loss: 0.1279 - val_accuracy: 0.8806 - val_loss: 0.4195
# Epoch 15/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9599 - loss: 0.1246 - val_accuracy: 0.8794 - val_loss: 0.4531
# Epoch 16/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9625 - loss: 0.1116 - val_accuracy: 0.8776 - val_loss: 0.4596
# Epoch 17/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9628 - loss: 0.1145 - val_accuracy: 0.8784 - val_loss: 0.4795
# Epoch 18/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9625 - loss: 0.1104 - val_accuracy: 0.8763 - val_loss: 0.4786
# Epoch 19/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9644 - loss: 0.1082 - val_accuracy: 0.8780 - val_loss: 0.5266
# Epoch 20/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9637 - loss: 0.1052 - val_accuracy: 0.8771 - val_loss: 0.5240
# Epoch 21/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9632 - loss: 0.1006 - val_accuracy: 0.8754 - val_loss: 0.5380
# Epoch 22/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9647 - loss: 0.1049 - val_accuracy: 0.8758 - val_loss: 0.5819
# Epoch 23/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9651 - loss: 0.0985 - val_accuracy: 0.8739 - val_loss: 0.5668
# Epoch 24/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9645 - loss: 0.0923 - val_accuracy: 0.8744 - val_loss: 0.6000
# Epoch 25/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9667 - loss: 0.0936 - val_accuracy: 0.8735 - val_loss: 0.6006
# Epoch 26/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.9678 - loss: 0.0910 - val_accuracy: 0.8709 - val_loss: 0.6172
# Epoch 27/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9669 - loss: 0.0886 - val_accuracy: 0.8750 - val_loss: 0.6432
# Epoch 28/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9691 - loss: 0.0866 - val_accuracy: 0.8737 - val_loss: 0.6646
# Epoch 29/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9659 - loss: 0.0881 - val_accuracy: 0.8745 - val_loss: 0.6921
# Epoch 30/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9685 - loss: 0.0876 - val_accuracy: 0.8746 - val_loss: 0.6914

# %%
drop_50_dict = drop_50_history.history

drop_50_loss = drop_50_dict['loss']
drop_50_val_loss = drop_50_dict['val_loss']
epochs = range(1, len(loss) + 1)

fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, 'b-', label='train_loss')
ax1.plot(epochs, val_loss, 'r-', label='val_loss')
ax1.plot(epochs, drop_20_loss, 'b--', label='train_loss (dropout 20%)')
ax1.plot(epochs, drop_20_val_loss, 'r--', label='val_loss (dropout 20%)')
ax1.plot(epochs, drop_50_loss, 'b:', label='train_loss (dropout 50%)')
ax1.plot(epochs, drop_50_val_loss, 'r:', label='val_loss (dropout 50%)')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

drop_50_accuracy = drop_50_dict['accuracy']
drop_50_val_accuracy = drop_50_dict['val_accuracy']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, accuracy, 'b-', label='train_accuracy')
ax2.plot(epochs, val_accuracy, 'r-', label='val_accuracy')
ax2.plot(epochs, drop_20_accuracy, 'b--', label='train_accuracy (dropout 20%)')
ax2.plot(epochs, drop_20_val_accuracy, 'r--', label='val_accuracy (dropout 20%)')
ax2.plot(epochs, drop_50_accuracy, 'b:', label='train_accuracy (dropout 50%)')
ax2.plot(epochs, drop_50_val_accuracy, 'r:', label='val_accuracy (dropout 50%)')
ax2.set_title('Train and Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()

# %% [markdown]
# # 최종 학습 정리
# 과대적합을 막기 위해 모델 크기 조절, 규제 적용, 드롭아웃을 적용해 보았다.
# 모델 크기는 데이터에 비해 모델이 너무 크면 과대적합이 발생할 수있기 때문에 규모에 따라 조절해주는 과정이였다.
# 먼저 모델 크기를 증가/감소를 시켜보고 직접 설정까지 해보았고 Dense와 epochs를 이용해 조절하였다.
# 다음으로는 규제를 적용해 보았는데 L1, L2, L1_L2의 조합을 적용해보았다.
# 규제는 과대적합이 발생하는 경우를 방지하기 위해 큰 가중치 값은 큰 규제를 가하는 방법이 규제화이다.
# 마지막으로 드롭아웃을 적용해 보았는데 모델이 학습할 때 사용하는 노드의 수를 전체 노드 중에서 일부만을 사용하는 방법이였다.
# 이번 학습에서는 20%적용과 50%를 적용해 학습을 해 보았다.
# 50% 적용의 경우 과대적합을 잘 잡는듯 했지만 훈련도 잘 안되는것을 볼 수 있었다.
